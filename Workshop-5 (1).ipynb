# %% [markdown]
# ### WORKSHOP - 5: License Plate Detection using OpenCV and Haar Cascade Classifier
# ### Name: VENKATANATHAN P R
# ### Reg.No: 212223240173

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('road_car.jpg')

# %%
def display(img):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(new_img)

# %%
display(img)

# %%
plate_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_russian_plate_number.xml')

# %%
def detect_plates(img):
    plate_img = img.copy()
    plate_rects = plate_cascade.detectMultiScale(plate_img,scaleFactor=1.1,minNeighbors=4,minSize=(30, 30))
    print(f"Total license plates detected: {len(plate_rects)}")
    for (x, y, w, h) in plate_rects:
        cv2.rectangle(plate_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
    return plate_img

# %%
result = detect_plates(img)
# Out:
# Total license plates detected: 2

# %%
display(result)
